# %% [markdown]
# # Herramienta GIT
#
# ## Sistema de control de versiones

# %% [markdown]
# Un sistema de control de versiones es un software que le permite al usuario contar con un orden sobre los archivos desarrollados para un proyecto. Estos sistemas facilitan el versionamiento de codigos, ya que al momento de actualizar, eliminar o crear archivos se "guarda" una version con los cambios nuevos y los anteriores creando una especie de arbol de los distintos archivos.

# %% [markdown]
# La forma en que Git maneja la información almacena es a traves de una serie de archivos y las modificaciones hechas al archivo se guardan "debajo" del mismo, de manera que retiene el archivo anterior y toma una "imagen" de este, Git maneja los archivos con una secuencia, si el archivo es igual que el anterior, solamente hace un enlace al archivo anterior.
#
# Git no permite cambiar los archivos sin que el sistema lo pase por alto ya que hace un checksum por cada archivo, esto quiere decir que los archivos no pueden ser corrompidos.

# %% [markdown]
# Git necesita pocos recursos de la pc, ya que lee directamente de la base de datos local, por lo que tampoco se estar conectado a internet.

# %% [markdown]
# #### Estados en GIT

# %% [markdown]
# Los estados de GIT pueden ser 3:
# <ol>
# <li>committed</li>
# <li>modified</li>
# <li>staged</li>
# </ol>

# %% [markdown]
# <strong> committed </strong> que significa que el archivo esta almacenado. <br>
# <strong> modified </strong> que significa que el archivo esta modificado pero no almacenado.<br>
# <strong> Staged </strong> que significa que se marco un archivo modificado en la actual version, marcada para el proximo modified.<br>

# %% [markdown]
# La manera en que Git funciona puede ser la siguiente: <br>
#
# <table>
# <tr>
# <th> Area de trabajo </th>
# <th> Directorio de Trabajo </th>
# <th> Repositorio Git </th>
# </tr>
#
# <tr>
# <td> Modificar los archivo </td>
# <td> Preparar los archivos </td>
# <td> Confirmar los cambios en el archivo </td>
# </tr>
#
# </table>

# %% [markdown]
# Algunos Comandos en GIT
#
# Listar los archivos
# ```git
# ls
# ```
# Listar los permisos de la carpeta
# ```git
# ls -l
# ```
# Limpiar la consola
# ```git
# clear
# ```

# %% [markdown]
# ![comandosDespliegue.PNG](attachment:comandosDespliegue.PNG)

# %% [markdown]
# Iniciar
# ```
# init
# ```
# ![init%20GIT%20OK.PNG](attachment:init%20GIT%20OK.PNG)

# %% [markdown]
# Estados
# ```
# status
# ```
# ![git%20status.PNG](attachment:git%20status.PNG)

# %% [markdown]
# agregar repositorio y ver su estado
# ```
# add .
# ```
# ![add.PNG](attachment:add.PNG)

# %% [markdown]
# ![mail%20y%20user.PNG](attachment:mail%20y%20user.PNG)
